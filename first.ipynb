# %% [markdown]
# # Virtual Environment (venv)
#
# A Virtual Environment is an isolated Python environment that allows each project to have its own packages and dependencies.
#
# ## Syntax
# python -m venv venv
#
#
# ### Explanation
#
# python → Runs the Python interpreter.
#
#
# -m → Runs a Python module.
#
#
# venv → Module used to create a virtual environment.
# venv (last) → Name of the virtual environment folder.
# Why Use Virtual Environment?
# Keeps project packages separate.
# Prevents version conflicts.
# Avoids installing packages globally.
# Makes projects easier to manage and share.

# %% [markdown]
# --
#
# ## for activate
#
#  venv\Scripts\activate.

# %% [markdown]
# 1. Create Virtual Environment
#         ↓
# python -m venv venv
#
#
#
#
# 2. Activate Virtual Environment
#         ↓
# venv\Scripts\activate
#
#
#
#
# 3. Install Required Packages
#         ↓
# pip install numpy ipykernel
#
#
#
#
# 4. Open Notebook (.ipynb)
#         ↓
# Select Kernel → venv
#
#
#
#
# 5. Run Python Code
